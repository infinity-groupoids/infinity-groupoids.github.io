# %% [markdown]
# # <center> Lab 3 Problems
#
# ## <center> Applications
#
# Add all needed libraries.

# %% [markdown]
# ### Problem 1
#
# The hydraulic press cylinder on a woodsplitter has a stroke of 2 feet (length). The maximum force
# the pump exerts when splitting the wood is variable depending on how far it is already extended. Few
# measurements of force are given below in the table (x denotes how far it is extended):![pump.png](attachment:pump.png)
#
# $$
# \begin{aligned}
# &\begin{array}{|c|c|c|c|c|c|c|c|}
# \hline \hline
# s & 0 & 1/3 & 2/3 & 1 & 4/3 & 5/3 & 2 \\
# \hline
# F(s) & 0 & 20,000 & 22,000 & 15,000 & 10,000 & 5,000 & 0\\
# \hline
# \end{array}
# \end{aligned}
# $$
#
# **a.** Find the model for this table as a fourth degree polynomial. Graph the data and the model.

# %% [markdown]
# **b.** Use the model to find approximate extension of cylinder when the force is maximum. What is the
# maximum force?

# %% [markdown]
# **Answer:**

# %% [markdown]
# **c.** Use the model to approximate work done in splitting the wood. (the pump will move full length)

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Problem 2
# ![scaled.0503_Web_GrandCanyonWest.030_t600.jpg](attachment:scaled.0503_Web_GrandCanyonWest.030_t600.jpg)

# %% [markdown]
# The Skywalk is a cantilever design, meaning that the observation platform extends over the rim of the
# canyon, with no visible means of support below it. Despite the lack of visible support posts or struts,
# cantilever structures are engineered to be very stable and the Skywalk is no exception. The observation
# platform is attached firmly to support posts that extend 46 ft down into bedrock. The structure was built
# to withstand 100 mph winds and an 8.0-magnitude earthquake within 50 mi, and is capable of supporting
# more than 70,000,000 lb.
#
# One factor affecting the stability of the Skywalk is the center of gravity of the structure. We are going to
# calculate the center of gravity of the Skywalk.
#
# The observation platform is U-shaped. The legs of the U are 10 ft wide and begin on land, under the
# visitors center, 48 ft from the edge of the canyon. The platform extends 70 ft over the edge of the canyon.
# To calculate the center of mass of the structure, we treat it as a lamina and use a two-dimensional region
# in the xy-plane to represent the platform. We begin by dividing the region into three subregions so we can
# consider each subregion separately. The first region, denoted R1, consists of the curved part of the U. We
# model R1 as a semicircular annulus, with inner radius 25 ft and outer radius 35 ft, centered at the origin
# (see the following figure).
#
# The legs of the platform, extending 35 ft between R1 and the canyon wall, comprise the second sub-region,
# R2. Last, the ends of the legs, which extend 48 ft under the visitor center, comprise the third sub-region,
# R3. Assume the density of the lamina is constant and assume the total weight of the platform is 1,200,000
# lb (not including the weight of the visitor center; we will consider that later).
# ![swdiag.png](attachment:swdiag.png)

# %% [markdown]
# **a.** Find the area of R1, R2, R3.

# %% [markdown]
# **b.** Find the weight of R1, R2, R3. (Reminder: the total weight of the Skywalk is 1,200,000 lb)

# %% [markdown]
# **c.** Find center of mass of R1, R2, R3. (In this problem you are allowed to use weight as mass. They are not
# the same thing, but it doesn't matter for calculating center of mass). You are allowed to use any rules and theorems to help you. Note the location of x-axis as well.

# %% [markdown]
# [NOTE]: Explain here what rules you will use if you are skipping some calculation

# %% [markdown]
# **Answer:**
#
# Coordinate for center of mass of R1 is
#
# Coordinate for center of mass of R2 is
#
# Coordinate for center of mass of R3 is

# %% [markdown]
# **d.** Treat all 3 regions as just a point with the same weight located at the center of their mass. Using this
# representation, calculate the center of mass of entire skywalk.

# %% [markdown]
# **Answer:**

# %% [markdown]
# **e.** Suppose the visitor center's weight is 2,200,000 lb and its center of mass coincides with center of mass
# of R3. If we add its weight to R3, where is the new center of mass of entire structure? Is the visitor center
# needed for skywalk to be stable? Why or why not?

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Problem 3
#
# Suppose we have a family of functions $f_n(x) = x^n$ between $x = 0$ and $x = 1$. Let $A_n$ be a region between
# $f_n(x)$ and x-axis.
#
# **a.** Set-up an indexed family of functions. Using it, find center of mass of $A_1$, $A_2$ and $A_3$.

# %% [markdown]
# **b.** Plot separately $f_1(x)$, $f_2(x)$, $f_3(x)$ and $f_4(x)$ with *their corresponding centers of mass* in a 2 by 2 grid.

# %% [markdown]
# **c.** As $n$ gets larger, where would center of mass approach?

# %% [markdown]
# **Answer:** As n gets larger, the center of mass approaches to (1,1/4)
