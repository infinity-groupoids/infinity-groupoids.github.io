# %% [markdown]
# # <center> Lab 6 Problems
# ## <center> Power Series and Parametric Functions
# Add all needed libraries.

# %% [markdown]
# ### Problem 1
#
# Let $f(x)=e^x\sin(x)$
#
# **a.** Graph $f(x)$ for $x\in(-4,4)$. Limit $y$ values to $(-4,4)$

# %% [markdown]
# **b.** We would want to approximate $f(1.5)$ in the next part. Let's see how well Maclaurin polynomial approximate our $f(x)$. Find Maclaurin polynomials with degrees 3, 5, 9, 21. Graph separatelly each of them together with f(x) to see
# how well they approximate near $1.5$. Use $x \in (0,3)$ and $y \in (0,7)$.
#
# If you would choose of these polynomials to approximate $f(1.5)$ but you would want to minimize the degree of it, which one would you choose?

# %% [markdown]
# **Answer:**

# %% [markdown]
# **c.** Compare approximation of $f(1.5)$ of four Taylor polynomials by finding the absolute value of the difference between $f(1.5)$ and Taylor polynomial evaluated at 1.5.

# %% [markdown]
# **d.** Based on your knowledge of the convergence of power series for $e^x$ and $\sin(x)$, what is the radius of convergence of $f(x)$.

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Problem 2
#
# In this problem we will try to solve hard integral called elliptic type integral. It is impossible to solve it by normal means.
# Even the answers you get from calculators are based on approximations we will do here.
#
# Let $f(x)=\frac{1}{\sqrt{2+\sin(x)}}$.
#
# **a.** Evaluate $\int_0^{\pi}f(x)dx$. Do it twice. Once without using `N` function and once with it. [It might take few seconds]. First one suggests that this doesnt have a nice closed form, but `N` manages to calculate it somehow

# %% [markdown]
# **b.** We will try to use Maclaurin polynomials first. Find Maclaurin polynomials for $f(x)$ of degree 5 and 15. Then plot each of them together with the graph of $f(x)$. If the y values get too high, limit them to $(-1,10)$.

# %% [markdown]
# **c.** There is something wrong here. We can't use Maclaurin polynomials for our integral. Why?

# %% [markdown]
# **Answer:**

# %% [markdown]
# **d.** **[Optional-Hard]** Can you figure out what is the radius of convergence of Maclauren series here?

# %% [markdown]
#  Hint to help you start: f(x) has discontinuity when $sin(x)=-2$. While this seems impossible, it is only impossible for real numbers.

# %% [markdown]
# **Answer:**

# %% [markdown]
# **e.** Let's change center point to $x=\frac{\pi}{2}$.
#
# Now, find Taylor polynomial for $f(x)$ of degree 4. Then plot it together with the graph of $f(x)$. Notice that even such low degree is already good enough.

# %% [markdown]
# **f.** Integrate this Taylor polynomial to approximate needed integral. How good is the approximation?
# (to find relative error of approximation calculate $Er =\frac{|a-s|}{s}\cdot 100 \%$
# , where $a$ is the approximation by Taylor polynomial and
# $s$ is the actual value of the integral found in part **a.**)  [Also, notice the difference in speed of calculating both integrals]

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Problem 3
#
# Plot parametric curve given by $x(t) = 2 \sin(t)- \sin(2t)$, $y(t) = 2 \cos(t)-\cos(2t)$ for $0\le t\le 2\pi$. This
# graph is called cardioid because of its shape. Compute arc length of this cardioid.

# %% [markdown]
# **Answer:**

# %% [markdown]
# **b.** We will consider now parametric function curve given by $x(t) = 16 \cos(t)-5 \cos(\frac{16t}{5})$, $y(t) = 16 \sin(t)-
# 5 \sin(\frac{16t}{5})$. It is called Epicycloid.
#
# First we want to know what is the range for t. We will try to guess. Plot the curve with a very large range:
# $0 \le t \le 20\pi$.

# %% [markdown]
# **b.** This is too much. To get a better range, consider the period of $x(t)$. The function $x(t)$ consist of two trigonometric functions $\cos(t)$ and $\cos(\frac{16t}{5})$. What is the period of each?
#
# Now you need a commom period. Consider mutiples of each period and find the first common one. The period of $y(t)$ is the same as $x(t)$ since it consists of similiar two functions; and so it will also be a period of the whole function.

# %% [markdown]
# **Answer:**

# %% [markdown]
# **b.** Plot the curve again, using correct upper bound.

# %% [markdown]
# **c.** Now that we know good upper bound, find the length of this curve. [It might take some time to calculate]

# %% [markdown]
# **Answer:**

# %% [markdown]
# ![image.png](attachment:image.png)
